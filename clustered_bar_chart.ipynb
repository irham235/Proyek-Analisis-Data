# %% [markdown]
# <a href="https://colab.research.google.com/github/irham235/Proyek-Analisis-Data/blob/main/clustered_bar_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

penguins = sns.load_dataset("penguins")

sns.barplot(data=penguins, x="species", y="body_mass_g", hue="sex", ci=None)
plt.show()
# Out:
# <ipython-input-1-e7a5f2de297f>:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=penguins, x="species", y="body_mass_g", hue="sex", ci=None)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e7a5f2de297f> in <cell line: 6>()
#       4
#       5 sns.barplot(data=penguins, x="species", y="body_mass_g", hue="sex", ci=None)
# ----> 6 plt.show()
#
# NameError: name 'plt' is not defined

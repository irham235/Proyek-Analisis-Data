# %% [markdown]
# <a href="https://colab.research.google.com/github/irham235/Proyek-Analisis-Data/blob/main/indonesia_youtube_trending.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Menggunakan Kaggle API

# %%
# !pip install -q kaggle

# %%
# !mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ref                                                             title                                            size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  ----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# iamsouravbanerjee/customer-shopping-trends-dataset              Customer Shopping Trends Dataset                146KB  2023-10-05 06:45:37          27260        536  1.0
# carlmcbrideellis/llm-7-prompt-training-dataset                  LLM: 7 prompt training dataset                   41MB  2023-11-15 07:32:56            583         58  1.0
# kzmontage/sales-from-different-stores                           Different Store Sales                             2MB  2023-11-11 18:24:54           1273         25  0.9411765
# ...

# %%
# !kaggle datasets download -d 'syahrulhamdani/indonesias-trending-youtube-video-statistics'
# Out:
# ...
#  95% 96.0M/101M [00:00<00:00, 181MB/s]
# 100% 101M/101M [00:00<00:00, 163MB/s]

# %%
import zipfile
dataset_zip = zipfile.ZipFile('indonesias-trending-youtube-video-statistics.zip', 'r')

dataset_zip.extractall()

dataset_zip.close()

# %% [markdown]
# ### Data Preprocessing

# %%
import pandas as pd

# input data
data = pd.read_csv('/content/trending.csv')
data.head()
# Out:
# <ipython-input-9-31a6b7ac80b2>:4: DtypeWarning: Columns (0,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/content/trending.csv')
#   video_id          publish_time                channel_id  \
# 0      NaN  2021-02-05T09:00:34Z  UCEf_Bc-KVd7onSeifS3py9g
# 1      NaN  2021-02-04T15:54:08Z  UCYEa4_MC7OFjcWrO6SO-u8g
# 2      NaN  2021-02-06T03:00:22Z  UCu12RxQjRQyh79YBYvEDkOg
# 3      NaN  2021-02-05T20:26:08Z  UCCuzDCoI3EUOo_nhCj4noSw
# 4      NaN  2021-02-03T23:14:54Z  UC14UlmYlSNiQCBe9Eookf_A
#
#                                                title  \
# 0                        aespa 에스파 'Forever (약속)' MV
# 1  [FULL] Siapa di Balik Kudeta AHY? | Dua Sisi t...
# 2     CABRIOLET CHALLENGE: TANTANGAN MENGGODA (7/12)
# 3                        With Windah Basudara & Hans
# 4  🤯 LATE COMEBACK DRAMA! | HIGHLIGHTS | Granada ...
#
#                                          description thumbnail_url  \
# ...

# %%
# tampilkan kolom
data.columns
# Out:
# Index(['video_id', 'publish_time', 'channel_id', 'title', 'description',
#        'thumbnail_url', 'thumbnail_width', 'thumbnail_height', 'channel_name',
#        'tags', 'category_id', 'live_status', 'local_title',
#        'local_description', 'duration', 'dimension', 'definition', 'caption',
#        'license_status', 'allowed_region', 'blocked_region', 'view', 'like',
#        'dislike', 'favorite', 'comment', 'trending_time'],
#       dtype='object')

# %%
# buat data baru berdasarkan kolom yang diinginkan saja

data = data[['title', 'channel_name', 'category_id', 'view', 'like',
       'dislike', 'comment', 'trending_time']]
data.head()
# Out:
#                                                title            channel_name  \
# 0                        aespa 에스파 'Forever (약속)' MV                  SMTOWN
# 1  [FULL] Siapa di Balik Kudeta AHY? | Dua Sisi t...  Indonesia Lawyers Club
# 2     CABRIOLET CHALLENGE: TANTANGAN MENGGODA (7/12)                Motomobi
# 3                        With Windah Basudara & Hans                      yb
# 4  🤯 LATE COMEBACK DRAMA! | HIGHLIGHTS | Granada ...            FC Barcelona
#
#    category_id       view      like  dislike  comment  \
# 0           10  7806846.0  857902.0  24078.0  94961.0
# 1           25   885038.0    6765.0   1263.0   6365.0
# 2            2   889708.0   47895.0    532.0   8785.0
# 3           20  1006854.0   91973.0   3967.0  12957.0
# 4           17  6275035.0  218131.0   4289.0  12799.0
#
#                       trending_time
# 0  2021-02-07 05:46:51.832614+00:00
# 1  2021-02-07 05:46:51.832649+00:00
# 2  2021-02-07 05:46:51.832664+00:00
# ...

# %%
# ubah category_id menjadi category_name
# tetapi sebelum itu harus meng import category_names terlebih dahulu

import json

with open("/content/category.json", "rb") as f:
  categories = json.load(f)

# %%
categories
# Out:
# {'kind': 'youtube#videoCategoryListResponse',
#  'etag': '_S1MAxBhP9n7eQUvtH1duuWAwbw',
#  'items': [{'kind': 'youtube#videoCategory',
#    'etag': 'grPOPYEUUZN3ltuDUGEWlrTR90U',
#    'id': '1',
#    'snippet': {'title': 'Film & Animation',
#     'assignable': True,
#     'channelId': 'UCBR8-60-B28hp2BmDPdntcQ'}},
#   {'kind': 'youtube#videoCategory',
#    'etag': 'Q0xgUf8BFM8rW3W0R9wNq809xyA',
#    'id': '2',
#    'snippet': {'title': 'Autos & Vehicles',
#     'assignable': True,
#     'channelId': 'UCBR8-60-B28hp2BmDPdntcQ'}},
#   {'kind': 'youtube#videoCategory',
#    'etag': 'qnpwjh5QlWM5hrnZCvHisquztC4',
#    'id': '10',
#    'snippet': {'title': 'Music',
#     'assignable': True,
#     'channelId': 'UCBR8-60-B28hp2BmDPdntcQ'}},
#   {'kind': 'youtube#videoCategory',
#    'etag': 'HyFIixS5BZaoBdkQdLzPdoXWipg',
#    'id': '15',
#    'snippet': {'title': 'Pets & Animals',
#     'assignable': True,
#     'channelId': 'UCBR8-60-B28hp2BmDPdntcQ'}},
# ...

# %%
categories = pd.json_normalize(categories, record_path="items")
categories_dict = {idx:title for idx, title in zip(categories['id'], categories['snippet.title'])}

# %%
from re import X
# ubah data category_id menjadi category di kolom baru
data['category'] = [categories_dict[str(x)] if str(x) in list(categories_dict.keys()) else "Unknown" for x in data['category_id']]

# %%
data
# Out:
#                                                     title  \
# 0                             aespa 에스파 'Forever (약속)' MV
# 1       [FULL] Siapa di Balik Kudeta AHY? | Dua Sisi t...
# 2          CABRIOLET CHALLENGE: TANTANGAN MENGGODA (7/12)
# 3                             With Windah Basudara & Hans
# 4       🤯 LATE COMEBACK DRAMA! | HIGHLIGHTS | Granada ...
# ...                                                   ...
# 172342  IBT 167: A IKY BONGKAR GEBETAN BARU SULE?! TEB...
# 172343  Sangkolan 1 | short movie madura ( SUB INDONES...
# 172344  BONGKAR RUMAH MASA KECILKU DI DESA WAJOK HILIR...
# 172345  Apakah Ini KODE KERAS Zidan ‼️ Merayu Mbak Yay...
# 172346  Emak-emak Korea protes sepanjang malam krn bel...
#
#                   channel_name  category_id       view      like  dislike  \
# 0                       SMTOWN           10  7806846.0  857902.0  24078.0
# 1       Indonesia Lawyers Club           25   885038.0    6765.0   1263.0
# ...

# %%
# lihat semua kategori dan jumlah mereka
data['category'].value_counts()
# Out:
# Entertainment           48625
# Music                   39986
# People & Blogs          21094
# Gaming                  16486
# Sports                  14790
# News & Politics          7679
# Film & Animation         6122
# Comedy                   4971
# Autos & Vehicles         3929
# Howto & Style            2330
# Science & Technology     2204
# Pets & Animals           1344
# Education                1278
# Travel & Events          1023
# Unknown                   486
# Name: category, dtype: int64

# %%
# cek jika ada nilai yang bernilai NA
data.isnull().sum()
# Out:
# title                 0
# channel_name          0
# category_id           0
# view                 10
# like               1321
# dislike          118717
# comment             483
# trending_time         0
# category              0
# dtype: int64

# %%
# mengubah semua nilai bernilai NA menjadi 0
data = data.fillna(0)

# %%
# cek kembali
data.isnull().sum()
# Out:
# title            0
# channel_name     0
# category_id      0
# view             0
# like             0
# dislike          0
# comment          0
# trending_time    0
# category         0
# dtype: int64

# %%
# mencari nilai trending_date dan menghapus trending_time
trending = pd.to_datetime(data['trending_time'])
data['trending_date'] = trending.dt.date
data = data.drop(['trending_time'], axis=1)

# %%
data
# Out:
#                                                     title  \
# 0                             aespa 에스파 'Forever (약속)' MV
# 1       [FULL] Siapa di Balik Kudeta AHY? | Dua Sisi t...
# 2          CABRIOLET CHALLENGE: TANTANGAN MENGGODA (7/12)
# 3                             With Windah Basudara & Hans
# 4       🤯 LATE COMEBACK DRAMA! | HIGHLIGHTS | Granada ...
# ...                                                   ...
# 172342  IBT 167: A IKY BONGKAR GEBETAN BARU SULE?! TEB...
# 172343  Sangkolan 1 | short movie madura ( SUB INDONES...
# 172344  BONGKAR RUMAH MASA KECILKU DI DESA WAJOK HILIR...
# 172345  Apakah Ini KODE KERAS Zidan ‼️ Merayu Mbak Yay...
# 172346  Emak-emak Korea protes sepanjang malam krn bel...
#
#                   channel_name  category_id       view      like  dislike  \
# 0                       SMTOWN           10  7806846.0  857902.0  24078.0
# 1       Indonesia Lawyers Club           25   885038.0    6765.0   1263.0
# ...

# %%
# melihat daya duplikat
data[['title', 'channel_name']].value_counts().reset_index(name='counts')
# Out:
#                                                    title  \
# 0      Top Lagu Pop Indonesia Terbaru 2021 Hits Pilih...
# 1      Official Trailer | She-Hulk: Attorney at Law |...
# 2      TANGMO NIDA: UPDATE PENEMUAN BUKTI2 TERBARU!! ...
# 3      HEBOH PAK MUH JUALAN BAKSO MERCON FULL CABE RA...
# 4      JEJE PENGHUNI STASIUN DUKUH ATAS, PERNAH CABUT...
# ...                                                  ...
# 24753  Visual Kapal Selam KRI Nanggala 402, Terbagi M...
# 24754                  Vita Alvia - CINTA MEMBAWA DERITA
# 24755     Siapa yang Tinggal di Tempat Terdalam di Bumi?
# 24756                                Bila Dia Menyukaiku
# 24757  Tora Sudiro Yang Diroasting, Yang Panik Semua ...
#
#                   channel_name  counts
# 0                 nayan barari      78
# 1         Marvel Entertainment      38
# 2                 Nessie Judge      37
# 3                Farida Nurhan      37
# 4                      Fuji an      37
# ...                        ...     ...
# ...

# %%
# hapus semua data duplikat
used_data = data.drop_duplicates(['title', 'channel_name'], keep='first')

# %%
used_data = used_data.reset_index(drop=True)

# %%
used_data
# Out:
#                                                    title  \
# 0                            aespa 에스파 'Forever (약속)' MV
# 1      [FULL] Siapa di Balik Kudeta AHY? | Dua Sisi t...
# 2         CABRIOLET CHALLENGE: TANTANGAN MENGGODA (7/12)
# 3                            With Windah Basudara & Hans
# 4      🤯 LATE COMEBACK DRAMA! | HIGHLIGHTS | Granada ...
# ...                                                  ...
# 24753                 GUNUNG DJADI - Atap Negeri Riau #2
# 24754                 Japri Nikah Siri, Paing Jadi Sirik
# 24755  PELANGGAN JAUH-JAUH DATANG DARI KOTA DALIAN BE...
# 24756  Q&A sambil makan PADANG di Pasar Senen ft. Jes...
# 24757                ONE PIECE | Final Trailer | Netflix
#
#                  channel_name  category_id       view      like  dislike  \
# 0                      SMTOWN           10  7806846.0  857902.0  24078.0
# 1      Indonesia Lawyers Club           25   885038.0    6765.0   1263.0
# ...

# %%
# menghapus category_id karena tidak dibutuhkan

used_data = used_data.drop(['category_id'], axis=1)
used_data
# Out:
#                                                    title  \
# 0                            aespa 에스파 'Forever (약속)' MV
# 1      [FULL] Siapa di Balik Kudeta AHY? | Dua Sisi t...
# 2         CABRIOLET CHALLENGE: TANTANGAN MENGGODA (7/12)
# 3                            With Windah Basudara & Hans
# 4      🤯 LATE COMEBACK DRAMA! | HIGHLIGHTS | Granada ...
# ...                                                  ...
# 24753                 GUNUNG DJADI - Atap Negeri Riau #2
# 24754                 Japri Nikah Siri, Paing Jadi Sirik
# 24755  PELANGGAN JAUH-JAUH DATANG DARI KOTA DALIAN BE...
# 24756  Q&A sambil makan PADANG di Pasar Senen ft. Jes...
# 24757                ONE PIECE | Final Trailer | Netflix
#
#                  channel_name       view      like  dislike  comment  \
# 0                      SMTOWN  7806846.0  857902.0  24078.0  94961.0
# 1      Indonesia Lawyers Club   885038.0    6765.0   1263.0   6365.0
# 2                    Motomobi   889708.0   47895.0    532.0   8785.0
# ...

# %% [markdown]
# menyimpan semua file ke bentuk pickle

# %% [markdown]
# mengapa menggunakan pickle, karena data dengan format pickle tidak mengubah bentuk dari data tersebut, pickle juga memiliki ukuran yang sangat kecil, jadi bisa menyimpan data yang besar di memori yang lebih kecil

# %%
used_data.to_pickle('/content/used_data.pickle')
